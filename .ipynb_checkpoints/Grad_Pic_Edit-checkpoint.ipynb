# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# Import grad pic and watermark
img = cv.imread("imgAssets/grad_pic.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
watermark = cv.imread("imgAssets/mask.png", 0)

plt.imshow(img)
plt.xticks([]), plt.yticks([])
plt.show()

plt.imshow(watermark, cmap="gray")
plt.xticks([]), plt.yticks([])
plt.show()
